# %%
# load necessary libraries
import pandas as pd
import pprint
import os
# import glob

# %%
# import csvs
paris_csv = "/Users/AttiasC16/Desktop/Paris.csv"
bangkok_csv = "/Users/AttiasC16/Desktop/Bangkok.csv"
newyork_csv = "/Users/AttiasC16/Desktop/NewYork.csv"
london_csv = "/Users/AttiasC16/Desktop/London.csv"
hongkong_csv = "/Users/AttiasC16/Desktop/HongKong.csv"
singapore_csv = "/Users/AttiasC16/Desktop/Singapore.csv"
instanbul_csv = "/Users/AttiasC16/Desktop/Instanbul.csv"

# %%
# read csv into pandas df
paris_df = pd.read_csv(paris_csv)
bangkok_df = pd.read_csv(bangkok_csv)
newyork_df = pd.read_csv(newyork_csv)
london_df = pd.read_csv(london_csv)
hongkong_df = pd.read_csv(hongkong_csv)
singapore_df = pd.read_csv(singapore_csv)
instanbul_df = pd.read_csv(instanbul_csv)
# Out:
# /var/folders/s8/06x09z5j12g_t79tbrhn448w0000gn/T/ipykernel_3210/3865770108.py:4: DtypeWarning: Columns (68) have mixed types. Specify dtype option on import or set low_memory=False.
#   newyork_df = pd.read_csv(newyork_csv)

# %%
# add "city" column to each df 
paris_df["city"] = "paris"
bangkok_df["city"] = "bangkok"
newyork_df["city"] = "newyork"
london_df["city"] = "london"
hongkong_df["city"] = "hongkong"
singapore_df["city"] = "singapore"
instanbul_df["city"] = "instanbul"

# %%
# convert price to USD
 
# conversion rate (as of 2023-03-30)

    # London (pounds) 1 pound = 1.24 usd
    # Paris (euro) 1 euro = 1.09 usd
    # Instanbul (lira) 1 lira = 0.052 usd
    # Bangkok (thai baht) 1 thai baht = 0.029 usd
    # Hong Kong (hong kong dollar) 1 hong kong dollar = 0.13 usd
    # Singapore (singapore dollar) 1 singapore dollar = 0.75 usd

# %%
# convert paris
paris_df['price'] = paris_df['price'].str.replace(',', '').str.replace('$', '')
# Out:
# /var/folders/s8/06x09z5j12g_t79tbrhn448w0000gn/T/ipykernel_3210/1399371155.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   paris_df['price'] = paris_df['price'].str.replace(',', '').str.replace('$', '')

# %%
paris_df['price'] = pd.to_numeric(paris_df['price'])

# %%
paris_df['USD_price'] = paris_df['price']*1.09

# %%
# convert london

# %%
london_df['price'] = london_df['price'].str.replace(',', '').str.replace('$', '')
# Out:
# /var/folders/s8/06x09z5j12g_t79tbrhn448w0000gn/T/ipykernel_3210/1519129439.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   london_df['price'] = london_df['price'].str.replace(',', '').str.replace('$', '')

# %%
london_df['price'] = pd.to_numeric(london_df['price'])

# %%
london_df['USD_price'] = london_df['price']*1.24

# %%
# convert instanbul

# %%
instanbul_df['price'] = instanbul_df['price'].str.replace(',', '').str.replace('$', '')
# Out:
# /var/folders/s8/06x09z5j12g_t79tbrhn448w0000gn/T/ipykernel_3210/942890720.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   instanbul_df['price'] = instanbul_df['price'].str.replace(',', '').str.replace('$', '')

# %%
instanbul_df['price'] = pd.to_numeric(instanbul_df['price'])

# %%
instanbul_df['USD_price'] = instanbul_df['price']*0.052

# %%
# convert bangkok

# %%
bangkok_df['price'] = bangkok_df['price'].str.replace(',', '').str.replace('$', '')
# Out:
# /var/folders/s8/06x09z5j12g_t79tbrhn448w0000gn/T/ipykernel_3210/508247684.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   bangkok_df['price'] = bangkok_df['price'].str.replace(',', '').str.replace('$', '')

# %%
bangkok_df['price'] = pd.to_numeric(bangkok_df['price'])

# %%
bangkok_df['USD_price'] = bangkok_df['price']*0.029

# %%
# convert hong kong

# %%
hongkong_df['price'] = hongkong_df['price'].str.replace(',', '').str.replace('$', '')
# Out:
# /var/folders/s8/06x09z5j12g_t79tbrhn448w0000gn/T/ipykernel_3210/2212592989.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   hongkong_df['price'] = hongkong_df['price'].str.replace(',', '').str.replace('$', '')

# %%
hongkong_df['price'] = pd.to_numeric(hongkong_df['price'])

# %%
hongkong_df['USD_price'] = hongkong_df['price']*0.13

# %%
# convert singapore

# %%
singapore_df['price'] = singapore_df['price'].str.replace(',', '').str.replace('$', '')
# Out:
# /var/folders/s8/06x09z5j12g_t79tbrhn448w0000gn/T/ipykernel_3210/3150728733.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   singapore_df['price'] = singapore_df['price'].str.replace(',', '').str.replace('$', '')

# %%
singapore_df['price'] = pd.to_numeric(singapore_df['price'])

# %%
singapore_df['USD_price'] = singapore_df['price']*0.75

# %%
# count number of rows in each df
paris_length = len(paris_df["id"])
bangkok_length = len(bangkok_df["id"])
newyork_length = len(newyork_df["id"])
london_length = len(london_df["id"])
hongkong_length = len(hongkong_df["id"])
singapore_length = len(singapore_df["id"])
instanbul_length = len(instanbul_df["id"])
print(f"paris length: {paris_length}")
print(f"bangkok length: {bangkok_length}")
print(f"newyork length: {newyork_length}")
print(f"london length: {london_length}")
print(f"hongkong length: {hongkong_length}")
print(f"singapore length: {singapore_length}")
print(f"instanbul length: {instanbul_length}")
# Out:
# paris length: 55104
# bangkok length: 15854
# newyork length: 41533
# london length: 71938
# hongkong length: 5194
# singapore length: 3037
# instanbul length: 36717

# %%
# find length of all dfs (make sure it matches merged_df)
combined_length = paris_length + bangkok_length + newyork_length + london_length + hongkong_length + singapore_length + instanbul_length
combined_length
# Out:
# 229377

# %%
# display dataframe 
#paris_df.head()
#bangkok_df.head()
#newyork_df.head()
#london_df.head()
#hongkong_df.head()
#singapore_df.head()
#instanbul_df.head()

# %%
# look at headers
#paris_df.columns 
for x in paris_df.columns: 
    print(x)
# Out:
# id
# listing_url
# scrape_id
# last_scraped
# source
# name
# description
# neighborhood_overview
# picture_url
# host_id
# host_url
# host_name
# host_since
# host_location
# host_about
# host_response_time
# host_response_rate
# host_acceptance_rate
# host_is_superhost
# host_thumbnail_url
# host_picture_url
# host_neighbourhood
# host_listings_count
# host_total_listings_count
# host_verifications
# host_has_profile_pic
# host_identity_verified
# neighbourhood
# neighbourhood_cleansed
# neighbourhood_group_cleansed
# latitude
# longitude
# property_type
# room_type
# accommodates
# bathrooms
# bathrooms_text
# bedrooms
# beds
# amenities
# price
# minimum_nights
# maximum_nights
# minimum_minimum_nights
# maximum_minimum_nights
# minimum_maximum_nights
# maximum_maximum_nights
# minimum_nights_avg_ntm
# maximum_nights_avg_ntm
# calendar_updated
# has_availability
# availability_30
# availability_60
# availability_90
# availability_365
# calendar_last_scraped
# number_of_reviews
# number_of_reviews_ltm
# number_of_reviews_l30d
# first_review
# last_review
# review_scores_rating
# review_scores_accuracy
# review_scores_cleanliness
# review_scores_checkin
# review_scores_communication
# review_scores_location
# review_scores_value
# license
# instant_bookable
# calculated_host_listings_count
# calculated_host_listings_count_entire_homes
# calculated_host_listings_count_private_rooms
# calculated_host_listings_count_shared_rooms
# reviews_per_month
# city
# USD_price

# %%
# merge into one df
merged_df = pd.concat([paris_df, bangkok_df, newyork_df, london_df, hongkong_df, singapore_df, instanbul_df])
merged_df.head()
# Out:
#         id                         listing_url     scrape_id last_scraped  \
# 0   5396.0   https://www.airbnb.com/rooms/5396  2.022120e+13     12/11/22
# 1   7397.0   https://www.airbnb.com/rooms/7397  2.022120e+13     12/11/22
# 2   7964.0   https://www.airbnb.com/rooms/7964  2.022120e+13     12/11/22
# 3   9359.0   https://www.airbnb.com/rooms/9359  2.022120e+13     12/11/22
# 4  81870.0  https://www.airbnb.com/rooms/81870  2.022120e+13     12/11/22
#
#             source                                             name  \
# 0      city scrape                   Explore the heart of old Paris
# 1      city scrape                 MARAIS - 2ROOMS APT - 2/4 PEOPLE
# 2  previous scrape                Large & sunny flat with balcony !
# 3      city scrape  Cozy, Central Paris: WALK or VELIB EVERYWHERE !
# 4  previous scrape                      Saint Germain Musee d'orsay
#
#                                          description  \
# 0  Cozy, well-appointed and graciously designed s...
# 1  VERY CONVENIENT, WITH THE BEST LOCATION !<br /...
# 2  Very large & nice apartment all for you! <br /...
# 3  Location! Location! Location! Just bring your ...
# 4  <b>The space</b><br />This beautiful apartment...
#
#                                neighborhood_overview  \
# 0  You are within walking distance to the Louvre,...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          picture_url  host_id  ...  \
# 0  https://a0.muscache.com/pictures/52413/f9bf76f...     7903  ...
# 1  https://a0.muscache.com/pictures/67928287/330b...     2626  ...
# 2  https://a0.muscache.com/pictures/4471349/6fb3d...    22155  ...
# 3  https://a0.muscache.com/pictures/c2965945-061f...    28422  ...
# 4  https://a0.muscache.com/pictures/558458/3c1263...   152242  ...
#
#   review_scores_value                                            license  \
# 0                4.55                                         7.5104E+12
# 1                4.72                                         7.5104E+12
# 2                5.00                                         7.5109E+12
# 3                 NaN  Available with a mobility lease only ("bail mo...
# 4                4.00                                                NaN
#
#   instant_bookable calculated_host_listings_count  \
# 0                f                              1
# 1                f                              2
# 2                f                              1
# 3                f                              1
# 4                f                             78
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           1
# 1                                           2
# 2                                           1
# 3                                           1
# 4                                          78
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month   city  \
# 0                                           0              1.98  paris
# 1                                           0              2.26  paris
# 2                                           0              0.04  paris
# 3                                           0               NaN  paris
# 4                                           0              0.01  paris
#
#   USD_price
# 0    101.37
# 1    129.71
# 2    141.70
# 3     81.75
# 4    158.05
#
# [5 rows x 77 columns]

# %%
### IF merging csv files 
# list all csv files only
#csv_files = glob.glob('*.{}'.format('csv'))
#csv_files
# merge files 
#merged_df = pd.concat([pd.read_csv(x) for x in csv_files ], ignore_index=True)
#merged_df.head()

# %%
# count number of rows to make sure all merged
merged_length = len(merged_df["id"]) 
merged_length
# Out:
# 229377

# %%
# look at columns 
for x in merged_df.columns: 
    print(x)
# Out:
# id
# listing_url
# scrape_id
# last_scraped
# source
# name
# description
# neighborhood_overview
# picture_url
# host_id
# host_url
# host_name
# host_since
# host_location
# host_about
# host_response_time
# host_response_rate
# host_acceptance_rate
# host_is_superhost
# host_thumbnail_url
# host_picture_url
# host_neighbourhood
# host_listings_count
# host_total_listings_count
# host_verifications
# host_has_profile_pic
# host_identity_verified
# neighbourhood
# neighbourhood_cleansed
# neighbourhood_group_cleansed
# latitude
# longitude
# property_type
# room_type
# accommodates
# bathrooms
# bathrooms_text
# bedrooms
# beds
# amenities
# price
# minimum_nights
# maximum_nights
# minimum_minimum_nights
# maximum_minimum_nights
# minimum_maximum_nights
# maximum_maximum_nights
# minimum_nights_avg_ntm
# maximum_nights_avg_ntm
# calendar_updated
# has_availability
# availability_30
# availability_60
# availability_90
# availability_365
# calendar_last_scraped
# number_of_reviews
# number_of_reviews_ltm
# number_of_reviews_l30d
# first_review
# last_review
# review_scores_rating
# review_scores_accuracy
# review_scores_cleanliness
# review_scores_checkin
# review_scores_communication
# review_scores_location
# review_scores_value
# license
# instant_bookable
# calculated_host_listings_count
# calculated_host_listings_count_entire_homes
# calculated_host_listings_count_private_rooms
# calculated_host_listings_count_shared_rooms
# reviews_per_month
# city
# USD_price

# %%
# delete columns not needed 
delete_columns_df = merged_df.drop(['scrape_id', 'last_scraped', 'source', 'host_id', 'host_url', 'host_location', 'host_about', 
                'host_response_time', 'host_acceptance_rate', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 
                'host_total_listings_count', 'host_verifications', 'host_has_profile_pic', 'host_identity_verified', 
                'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'bathrooms', 'minimum_minimum_nights', 
                'maximum_minimum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm',
                'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability', 'availability_30', 'availability_60',
                'availability_90', 'availability_365', 'calendar_last_scraped', 'number_of_reviews', 'number_of_reviews_ltm', 
                'number_of_reviews_l30d', 'first_review', 'last_review', 'review_scores_accuracy', 'review_scores_checkin', 
                'review_scores_location', 'review_scores_value', 'license', 'instant_bookable', 'calculated_host_listings_count', 
               'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 
                'calculated_host_listings_count_shared_rooms', 'reviews_per_month', 'neighborhood_overview', 
                'minimum_nights', 'maximum_nights', 'price', 'host_listings_count'], axis=1)
delete_columns_df.head()
# Out:
#         id                         listing_url  \
# 0   5396.0   https://www.airbnb.com/rooms/5396
# 1   7397.0   https://www.airbnb.com/rooms/7397
# 2   7964.0   https://www.airbnb.com/rooms/7964
# 3   9359.0   https://www.airbnb.com/rooms/9359
# 4  81870.0  https://www.airbnb.com/rooms/81870
#
#                                               name  \
# 0                   Explore the heart of old Paris
# 1                 MARAIS - 2ROOMS APT - 2/4 PEOPLE
# 2                Large & sunny flat with balcony !
# 3  Cozy, Central Paris: WALK or VELIB EVERYWHERE !
# 4                      Saint Germain Musee d'orsay
#
#                                          description  \
# 0  Cozy, well-appointed and graciously designed s...
# 1  VERY CONVENIENT, WITH THE BEST LOCATION !<br /...
# 2  Very large & nice apartment all for you! <br /...
# 3  Location! Location! Location! Just bring your ...
# 4  <b>The space</b><br />This beautiful apartment...
#
#                                          picture_url   host_name host_since  \
# 0  https://a0.muscache.com/pictures/52413/f9bf76f...      Borzou    2/14/09
# 1  https://a0.muscache.com/pictures/67928287/330b...      Franck    8/30/08
# 2  https://a0.muscache.com/pictures/4471349/6fb3d...       Anaïs    6/18/09
# 3  https://a0.muscache.com/pictures/c2965945-061f...  Bernadette    7/29/09
# 4  https://a0.muscache.com/pictures/558458/3c1263...    Delphine    6/25/10
#
#   host_response_rate host_is_superhost                 neighbourhood  ...  \
# 0               100%                 f  Paris, Ile-de-France, France  ...
# 1               100%                 t                           NaN  ...
# 2                NaN                 f                           NaN  ...
# 3                NaN                 f                           NaN  ...
# 4                59%                 f                           NaN  ...
#
#    accommodates  bathrooms_text bedrooms beds  \
# 0             2          1 bath      NaN  1.0
# 1             4          1 bath      2.0  2.0
# 2             2          1 bath      1.0  1.0
# 3             1          1 bath      1.0  1.0
# 4             2          1 bath      1.0  1.0
#
#                                            amenities review_scores_rating  \
# 0  ["Cleaning products", "Oven", "Host greets you...                 4.55
# 1  ["Free washer \u2013 In unit", "Oven", "Host g...                 4.72
# 2  ["Cleaning products", "Free washer \u2013 In u...                 4.80
# 3  ["Long term stays allowed", "Dedicated workspa...                  NaN
# 4  ["Oven", "Host greets you", "Coffee maker", "C...                 5.00
#
#    review_scores_cleanliness  review_scores_communication   city  USD_price
# 0                       4.51                         4.82  paris     101.37
# 1                       4.43                         4.88  paris     129.71
# 2                       5.00                         5.00  paris     141.70
# 3                        NaN                          NaN  paris      81.75
# 4                       5.00                         5.00  paris     158.05
#
# [5 rows x 24 columns]

# %%
# look at columns 
for x in delete_columns_df.columns: 
    print(x)
# Out:
# id
# listing_url
# name
# description
# picture_url
# host_name
# host_since
# host_response_rate
# host_is_superhost
# neighbourhood
# latitude
# longitude
# property_type
# room_type
# accommodates
# bathrooms_text
# bedrooms
# beds
# amenities
# review_scores_rating
# review_scores_cleanliness
# review_scores_communication
# city
# USD_price

# %%
# remove any rows containing n/a
cleaned_df = delete_columns_df.dropna()
cleaned_df.head()
# Out:
#          id                         listing_url  \
# 5    9952.0   https://www.airbnb.com/rooms/9952
# 6   84820.0  https://www.airbnb.com/rooms/84820
# 10  86053.0  https://www.airbnb.com/rooms/86053
# 23  11798.0  https://www.airbnb.com/rooms/11798
# 25  94270.0  https://www.airbnb.com/rooms/94270
#
#                                                  name  \
# 5                           Paris petit coin douillet
# 6   Bird's nest in Montmartre: Sun/view all over P...
# 10               Charmful flat facing a gothic church
# 23                        Loft very charming in Paris
# 25                   Artist's atelier in Montparnasse
#
#                                           description  \
# 5   Je suis une dame retraitée, qui propose un agr...
# 6   Apartment, two rooms, very calm and sunny.<br ...
# 10  Amazing apartment totally renovated facing one...
# 23  Mon appartement est situé dans une très jolie ...
# 25  Charming artist's atelier turned into a spacio...
#
#                                           picture_url  host_name host_since  \
# 5   https://a0.muscache.com/pictures/ae822d16-74d2...  Elisabeth    8/24/09
# 6   https://a0.muscache.com/pictures/581023/86105d...      Laure    3/26/11
# 10  https://a0.muscache.com/pictures/1982057/f94cf...    Richard   11/23/10
# 23  https://a0.muscache.com/pictures/22458692/09eb...   Laurence    10/8/09
# 25  https://a0.muscache.com/pictures/3155777/980bb...  Guglielmo    11/1/10
#
#    host_response_rate host_is_superhost  host_listings_count  ...  \
# 5                100%                 t                  1.0  ...
# 6                100%                 t                  1.0  ...
# 10               100%                 t                  1.0  ...
# 23               100%                 f                  1.0  ...
# 25               100%                 t                 34.0  ...
#
#    accommodates  bathrooms_text  bedrooms beds  \
# 5             2          1 bath       1.0  1.0
# 6             3       1.5 baths       1.0  1.0
# 10            4          1 bath       1.0  2.0
# 23            2          1 bath       1.0  1.0
# 25            4          1 bath       2.0  3.0
#
#                                             amenities  review_scores_rating  \
# 5   ["Oven", "Host greets you", "Coffee maker", "S...                  4.91
# 6   ["Free washer \u2013 In unit", "Oven", "Host g...                  4.87
# 10  ["Baking sheet", "Children\u2019s books and to...                  4.87
# 23  ["Oven", "Host greets you", "Coffee maker", "S...                  4.85
# 25  ["Ethernet connection", "Oven", "Host greets y...                  4.74
#
#    review_scores_cleanliness  review_scores_communication   city USD_price
# 5                       4.86                         4.84  paris    152.60
# 6                       4.86                         4.88  paris     90.47
# 10                      4.76                         4.95  paris    292.12
# 23                      4.82                         4.95  paris    141.70
# 25                      4.71                         4.93  paris    162.41
#
# [5 rows x 25 columns]

# %%
# export cleaned_df 
# cleaned_df.to_csv("/Users/AttiasC16/Desktop/cleaned.csv", index=False, header=True)

# %%
# count how many rows left after dropna
len(cleaned_df["id"])
# Out:
# 50227

# %%
# count how many listings each city has
cleaned_df["city"].value_counts()
# Out:
# london       20943
# paris        13435
# instanbul     8972
# bangkok       5065
# hongkong       916
# singapore      896
# Name: city, dtype: int64
